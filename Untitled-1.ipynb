# %%
#pip install psycopg2

# %%
# %run -i '/home/faizan/Function files RB/libraries.py'

# %%
#%run -i '/mnt/d/Rb Suggested Ordering System/ingest_dataframe.py'

# %%
# %run -i '/mnt/d/Rb Suggested Ordering System/injest_by_postgresql.py'
# Out:
#         Year Month Distributor                          Distributor_Name  \
# 0       2019     1    34140551  SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# 1       2019     1    34140551  SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# 2       2019     1    34140551  SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# 3       2019     1    34140551  SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# 4       2019     1    34140551  SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# ...      ...   ...         ...                                       ...
# 950891  2020    11    34140872           PREMIER SALES (PRIVATE) LIMITED
# 950892  2020    11    34140872           PREMIER SALES (PRIVATE) LIMITED
# 950893  2020    11    34140872           PREMIER SALES (PRIVATE) LIMITED
# 950894  2020    11    34140872           PREMIER SALES (PRIVATE) LIMITED
# 950895  2020    11    34140872           PREMIER SALES (PRIVATE) LIMITED
#
#        Invoice_Date Customer_Code     Customer_Name Route_Code  \
# ...

# %%
# %run -i '/mnt/d/Rb Suggested Ordering System/Select_Distributor_Name.py'
# Out:
# DISTRIBUTOR LIST
# 0         SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# 648206             PREMIER SALES (PRIVATE) LIMITED
# Name: Distributor_Name, dtype: object
#         Year Month Distributor                          Distributor_Name  \
# 0       2019     1    34140551  SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# 1       2019     1    34140551  SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# 2       2019     1    34140551  SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# 3       2019     1    34140551  SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# 4       2019     1    34140551  SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# ...      ...   ...         ...                                       ...
# 768184  2020    11    34140551  SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# 768185  2020    11    34140551  SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# 768186  2020    11    34140551  SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# 768187  2020    11    34140551  SHAN DISTRIBUTION SERVICES (PVT) LIMITED
# ...

# %%
# %run -i '/mnt/d/Rb Suggested Ordering System/cust-transaction.py'
# Out:
#        Customer_Code                    Customer_Name Route_Code  \
# 0           ISL00001                  Shaheen Chemist    SDSRC37
# 1           ISL00001                  Shaheen Chemist    SDSRC37
# 2           ISL00001                  Shaheen Chemist    SDSRC37
# 3           ISL00001                  Shaheen Chemist    SDSRC37
# 4           ISL00001                  Shaheen Chemist    SDSRC37
# ...              ...                              ...        ...
# 320827      RWP25757  Jade E services Pakistan ltd. S    SDSRC38
# 320828      RWP25757  Jade E services Pakistan ltd. S    SDSRC38
# 320829      RWP25757  Jade E services Pakistan ltd. S    SDSRC38
# 320830      RWP25757  Jade E services Pakistan ltd. S    SDSRC38
# 320831      RWP25757  Jade E services Pakistan ltd. S    SDSRC38
#
#                    Route_Name Product_Code  List_Price  Quantity_EA  \
# 0       Zone AH - ZEESHAN ISB      3011997      817.31            2
# ...

# %%
# %run -i '/mnt/d/Rb Suggested Ordering System/dummy_normalize_data.py'
# Out:
# (251140, 3)
#         Customer_Code Product_Code  scaled_purchase_freq
# 9            ISL00010      3011996                 0.000
# 19           ISL00021      3011996                 0.000
# 25           ISL00027      3011996                 0.125
# 27           ISL00029      3011996                 0.000
# 43           ISL00046      3011996                 0.125
# ...               ...          ...                   ...
# 2008377      RWP25699        95655                 0.000
# 2008387      RWP25709        95655                 0.000
# 2008395      RWP25720        95655                 0.000
# 2008407      RWP25737        95655                 0.000
# 2008408      RWP25738        95655                 0.000
#
# [251140 rows x 3 columns]

# %%
# %run -i '/mnt/d/Rb Suggested Ordering System/Split_data.py'

# %%
# %run -i '/mnt/d/Rb Suggested Ordering System/Cisone_Similarity_Model.py'
# Out:
# ...
#     To use these columns in scoring predictions, use a model that allows the use of additional features.
# Preparing data set.
#     Data has 256665 observations with 6559 users and 305 items.
#     Data prepared in: 0.56424s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 4.315ms                        | 15         |
# | 8.79ms                         | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# ...

# %%
# %run -i '/mnt/d/Rb Suggested Ordering System/Model_Evaluation.py'
# Out:
# recommendations finished on 456000/768189 queries. users per second: 24745.6
# recommendations finished on 457000/768189 queries. users per second: 24702.1
# PROGRESS: Evaluate model Cosine Similarity on Purchase Counts
# recommendations finished on 458000/768189 queries. users per second: 24714.2
# recommendations finished on 459000/768189 queries. users per second: 24709.1
# recommendations finished on 460000/768189 queries. users per second: 24726.2
# recommendations finished on 461000/768189 queries. users per second: 24719.4
# recommendations finished on 462000/768189 queries. users per second: 24690.7
# recommendations finished on 463000/768189 queries. users per second: 24684.3
# recommendations finished on 464000/768189 queries. users per second: 24679.1
# recommendations finished on 465000/768189 queries. users per second: 24683.1
# recommendations finished on 466000/768189 queries. users per second: 24695
# ...

# %%
# %run -i '/mnt/d/Rb Suggested Ordering System/Model_Selection.py'
# Out:
# ...
#     To use these columns in scoring predictions, use a model that allows the use of additional features.
# Preparing data set.
#     Data has 320832 observations with 6585 users and 305 items.
#     Data prepared in: 0.392229s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 1.511ms                        | 15         |
# | 5.982ms                        | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# ...

# %%
# %run -i '/mnt/d/Rb Suggested Ordering System/Popular_and_Non-Popular_dataframe.py'
# Out:
# recommendations finished on 723000/768189 queries. users per second: 25830.1
# recommendations finished on 724000/768189 queries. users per second: 25837.8
# recommendations finished on 725000/768189 queries. users per second: 25837.4
# recommendations finished on 726000/768189 queries. users per second: 25838.2
# recommendations finished on 727000/768189 queries. users per second: 25836.2
# recommendations finished on 728000/768189 queries. users per second: 25842.4
# recommendations finished on 729000/768189 queries. users per second: 25840.6
# recommendations finished on 730000/768189 queries. users per second: 25838.4
# (65850, 4)
# recommendations finished on 731000/768189 queries. users per second: 25839.7
# recommendations finished on 732000/768189 queries. users per second: 25838.5
# recommendations finished on 733000/768189 queries. users per second: 25821.1
# recommendations finished on 734000/768189 queries. users per second: 25808.9
# ...

# %%
# %run -i '/mnt/d/Rb Suggested Ordering System/Date_Difference_Dataframe.py'
# Out:
#        Customer_Code Invoice_Date  Sales of products
# 0           ISL00001   2019-01-09                  2
# 1           ISL00001   2019-01-17                  6
# 2           ISL00001   2019-01-23                 12
# 3           ISL00001   2019-01-29                  2
# 4           ISL00001   2019-02-06                  4
# ...              ...          ...                ...
# 159712      RWP25755   2020-10-20                 89
# 159713      RWP25756   2020-10-22                  1
# 159714      RWP25756   2020-11-05                  1
# 159715      RWP25757   2020-10-24                 37
# 159716      RWP25757   2020-11-24                 13
#
# [159717 rows x 3 columns]
#        Customer_Code Invoice_Date  Sales of products
# 0           ISL00001   2019-01-09                  2
# 1           ISL00001   2019-01-17                  6
# 2           ISL00001   2019-01-23                 12
# 3           ISL00001   2019-01-29                  2
# ...

# %%
# %run -i '/mnt/d/Rb Suggested Ordering System/Merging_Popular_and_Non-Popular.py'
# Out:
# Customer_Code           0
# Customer_Name           0
# Product_Code            0
# Product_Description     0
# Purchase_Count          0
# List_Price              0
# Expected_Quantity_EA    0
# Net_Amount              0
# dtype: int64
#       Customer_Code                    Customer_Name Product_Code  \
# 0          RWP25757  Jade E services Pakistan ltd. S      3076452
# 1          RWP25757  Jade E services Pakistan ltd. S      3035001
# 2          RWP25757  Jade E services Pakistan ltd. S      3012330
# 3          RWP25757  Jade E services Pakistan ltd. S      3012342
# 4          RWP25757  Jade E services Pakistan ltd. S      3012349
# ...             ...                              ...          ...
# 59687      ISL00001                  Shaheen Chemist      3012326
# 59688      ISL00001                  Shaheen Chemist      3023742
# 59689      ISL00001                  Shaheen Chemist      3023743
# 59690      ISL00001                  Shaheen Chemist      3091220
# ...

# %%
# %run -i '/mnt/d/Rb Suggested Ordering System/Merging_Route_plan_with_Final_Dataframe.py'
# Out:
# 0         SDSRC35
# 12        SDSRC33
# 14        SDSRC05
# 15        SDSRC36
# 20        SDSRC38
# 21        SDSRC31
# 25        SDSRC39
# 32        SDSRC07
# 37        SDSRC29
# 38        SDSRC15
# 51        SDSRC28
# 74        SDSRC37
# 88        SDSRC02
# 119       SDSRC34
# 125       SDSRC01
# 144       SDSRC24
# 155       SDSRC03
# 162       SDSRC10
# 254       SDSRC27
# 276       SDSRC08
# 279       SDSRC26
# 478       SDSRC32
# 1876      SDSRC09
# 198287    SDSRC13
# 641671    SDSRC40
# Name: Route_Code, dtype: object
#      Route_Code Customer_Code      Days
# 0       SDSRC05      RWP22334  Saturday
# 1       SDSRC05      RWP21053    Friday
# 2       SDSRC05      RWP20822    Monday
# 3       SDSRC05      RWP20820    Monday
# 4       SDSRC05      RWP20840    Monday
# ...         ...           ...       ...
# 1597    SDSRC08      RWP21966  Saturday
# 1598    SDSRC08      RWP21967  Saturday
# 1599    SDSRC08      RWP23593  Saturday
# 1600    SDSRC08      RWP23596    Monday
# ...

# %%
# %run -i '/mnt/d/Rb Suggested Ordering System/Merging_MSL-List_with_Final_Dataframe.py'
# Out:
#     Product_Code     MSL_List
# 0        3011997  MSL Product
# 1        3011999  MSL Product
# 2        3012326  MSL Product
# 3        3012327  MSL Product
# 4        3012329  MSL Product
# ..           ...          ...
# 105      3119304  MSL Product
# 106      3119305  MSL Product
# 107      8185631  MSL Product
# 108      8185633  MSL Product
# 109      8185651  MSL Product
#
# [110 rows x 2 columns]
# 46
# {'3011997',
#  '3012326',
#  '3012327',
#  '3012330',
#  '3012331',
#  '3012333',
#  '3012334',
#  '3012339',
#  '3012342',
#  '3012345',
#  '3012346',
#  '3017773',
#  '3017774',
#  '3017776',
#  '3017777',
#  '3017778',
#  '3023737',
#  '3023738',
#  '3023739',
#  '3023740',
#  '3023741',
#  '3023742',
#  '3023743',
#  '3023744',
#  '3023746',
#  '3029941',
#  '3029942',
#  '3029943',
#  '3062399',
#  '3065971',
#  '3090896',
#  '3090897',
#  '3090898',
#  '3090902',
#  '3091166',
#  '3091167',
#  '3091169',
#  '3091220',
#  '3093709',
#  '3093882',
#  '3093884',
# ...

# %%
#pip install SQLAlchemy

# %%
# %run -i '/mnt/d/Rb Suggested Ordering System/recom_database.py'
# Out:
# ['recom_for_PSKRC032020-11-30', 'rbpre']
# ['recom_for_PSKRC032020-11-30', 'recom_for_PSKRC042020-11-30', 'rbpre']
